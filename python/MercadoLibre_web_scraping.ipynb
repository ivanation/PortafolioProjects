# %%
from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime

# %%
URL = 'https://articulo.mercadolibre.com.ve/MLV-747151969-zapatos-lee-cooper-de-hombre-lc-807087m-035-_JM#position=2&search_layout=grid&type=item&tracking_id=e925f1be-0146-4c23-8805-b53b25cce58a&DEAL_ID=MLV6620&S=landingHubofertazo-moda&V=10&T=CarouselDynamic-normal&L=%C2%A1MAS-MODA,-MAS-DESCUENTOS!&deal_print_id=4ac46050-887c-11ee-bc86-7b0e8fac7eec&c_id=carouseldynamic-normal&c_element_order=undefined&c_campaign=%C2%A1MAS-MODA,-MAS-DESCUENTOS!&c_uid=4ac46050-887c-11ee-bc86-7b0e8fac7eec'

# https://httpbin.org/get
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}


page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")


print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html lang="es-VE">
# <head>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://www.google.com" rel="preconnect"/>
# <link href="https://data.mercadolibre.com" rel="preconnect"/>
# <link href="https://http2.mlstatic.com" rel="preconnect"/>
# <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
# <link href="https://analytics.mercadolibre.com.ve" rel="preconnect"/>
# <link href="https://analytics.mercadolibre.com" rel="preconnect"/>
# <link href="https://www.google.com.ve" rel="preconnect"/>
# <script nonce="3K0v6y9wePMpl/TKp7A8/g==" type="text/javascript">
# ...

# %%
title = soup2.find('h1',class_="ui-pdp-title").text
print(title)
# Out:
#               Zapatos Lee-cooper De Hombre Lc-807087m-035

# %%
price2 = soup2.find_all('span',class_="andes-money-amount__fraction")
price = price2[1].text
print(price)
# Out:
#                   27

# %%
type(price)
# Out:
# str

# %%
# Clean up the data a little bit

title = title.strip()
print(title)

price = price.strip()
print(price)
# Out:
# Zapatos Lee-cooper De Hombre Lc-807087m-035
# 27

# %%
# Create a Timestamp for the output to track when data was collected

import datetime

today = datetime.date.today()

print(today)
# Out:
# 2023-11-21

# %%
# Create CSV and write headers and data into the file

import csv 

header = ['Title', 'Price', 'Date']
data = [title, price, today]


with open('MercadoLibreScraperDataset.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r'MercadoLibreScraperDataset.csv')

print(df)
# Out:
#                                          Title  Price        Date
# 0  Zapatos Lee-cooper De Hombre Lc-807087m-035     27  2023-11-21
# 1  Zapatos Lee-cooper De Hombre Lc-807087m-035     27  2023-11-21

# %%
#Now we are appending data to the csv

with open('MercadoLibreScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
#Combine all of the above code into one function


def check_price():
    URL = 'https://articulo.mercadolibre.com.ve/MLV-747151969-zapatos-lee-cooper-de-hombre-lc-807087m-035-_JM#position=2&search_layout=grid&type=item&tracking_id=e925f1be-0146-4c23-8805-b53b25cce58a&DEAL_ID=MLV6620&S=landingHubofertazo-moda&V=10&T=CarouselDynamic-normal&L=%C2%A1MAS-MODA,-MAS-DESCUENTOS!&deal_print_id=4ac46050-887c-11ee-bc86-7b0e8fac7eec&c_id=carouseldynamic-normal&c_element_order=undefined&c_campaign=%C2%A1MAS-MODA,-MAS-DESCUENTOS!&c_uid=4ac46050-887c-11ee-bc86-7b0e8fac7eec'

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")

    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    title = soup2.find('h1',class_="ui-pdp-title").text

    price2 = soup2.find_all('span',class_="andes-money-amount__fraction")
    price = price2[1].text

    price = price.strip()
    title = title.strip()

    import datetime

    today = datetime.date.today()
    
    import csv 

    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open('MercadoLibreScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)
        
    #if price < 20:
        #send_mail()

# %%
# Checking the function

check_price()

df = pd.read_csv(r'MercadoLibreScraperDataset.csv')

print(df)
# Out:
#                                          Title  Price        Date
# 0  Zapatos Lee-cooper De Hombre Lc-807087m-035     27  2023-11-21
# 1  Zapatos Lee-cooper De Hombre Lc-807087m-035     27  2023-11-21
# 2  Zapatos Lee-cooper De Hombre Lc-807087m-035     27  2023-11-21

# %%
# Runs check_price after a set time and inputs data into your CSV

while(True):
    check_price()
    time.sleep(86400)

# %%
# sending yourself an email when a price hits below a certain level you can try it
# out with this script

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('aivan.alvarez@gmail.com','xxxxxxxxxxxxxx')
    
    subject = "The Item you want is below $20! Now is your chance to buy!"
    body = "Ivan, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://articulo.mercadolibre.com.ve/MLV-747151969-zapatos-lee-cooper-de-hombre-lc-807087m-035-_JM#position=2&search_layout=grid&type=item&tracking_id=e925f1be-0146-4c23-8805-b53b25cce58a&DEAL_ID=MLV6620&S=landingHubofertazo-moda&V=10&T=CarouselDynamic-normal&L=%C2%A1MAS-MODA,-MAS-DESCUENTOS!&deal_print_id=4ac46050-887c-11ee-bc86-7b0e8fac7eec&c_id=carouseldynamic-normal&c_element_order=undefined&c_campaign=%C2%A1MAS-MODA,-MAS-DESCUENTOS!&c_uid=4ac46050-887c-11ee-bc86-7b0e8fac7eec"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'aivan.alvarez@gmail.com',
        msg
     
    )
